# %% [markdown]
# # Case Study on ANOVA
# DataSet :Sales_data_zone_wise

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_df=pd.read_csv(r"C:\Users\vivek\Downloads\Untitled Folder\Week 8\Sales_data_zone_wise.csv")

# %%
sales_df.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
sales_df.shape
# Out:
# (29, 5)

# %% [markdown]
# # The mean sales generated by each zone.

# %%
sales_df[["Zone - A","Zone - B","Zone - C"]].mean(axis=0)
# Out:
# Zone - A    1.540493e+06
# Zone - B    1.755560e+06
# Zone - C    1.772871e+06
# dtype: float64

# %%
sales_df[["Zone - A","Zone - B","Zone - C"]].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Total sales generated by all the zones for each month

# %%
sales_df["Month_total"] = sales_df["Zone - A"] +sales_df["Zone - B"] +sales_df["Zone - C"] +sales_df["Zone - D"]

# %%
sales_df[["Month","Month_total"]]
# Out:
#          Month  Month_total
# 0    Month - 1      7022544
# 1    Month - 2      7152303
# 2    Month - 3      6475939
# 3    Month - 4      8174449
# 4    Month - 5      5995328
# 5    Month - 6      7151387
# 6    Month - 7      7287108
# 7    Month - 8      7816299
# 8    Month - 9      6703395
# 9   Month - 10      7128210
# 10  Month - 11      7032783
# 11  Month - 12      6111084
# 12  Month - 13      5925424
# 13  Month - 14      7155515
# 14  Month - 15      5934156
# 15  Month - 16      6506659
# 16  Month - 17      7149383
# 17  Month - 18      7083490
# 18  Month - 19      6971953
# 19  Month - 20      7124599
# 20  Month - 21      7389597
# 21  Month - 22      7560001
# 22  Month - 23      6687919
# 23  Month - 24      7784747
# 24  Month - 25      6095918
# 25  Month - 26      6512360
# 26  Month - 27      6267918
# 27  Month - 28      7470920
# 28  Month - 29      6772277

# %%
sales_df[["Month","Month_total"]].plot()

#plt.plot(sales_df["Month"], sales_df["Month_total"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Check whether all the zones generate the same amount of sales.
#
# Setting Hypothesis
#
# H0: All zones generates the same amount of sales
# H1: All zones generate different amount of sales

# %%
from scipy.stats import f_oneway

# %%
_, p=f_oneway(sales_df['Zone - A'],sales_df['Zone - B'],sales_df['Zone - C'],sales_df['Zone - D'])
alpha=0.05

# %%
print("Value of p" ,p)
# Out:
# Value of p 0.0011827601694503335

# %%
if p> alpha:
    print ('fail to reject the Null Hypothesis,H0')
else:
    print('Reject the Null Hypothesis,H0')
# Out:
# Reject the Null Hypothesis,H0

# %%
#Conclusion:
    # Based on the testing carried out in the provided data, we are rejecting null hypothesis 
    # We can conclude that There is an atleast one zone has a different mean
